# %% [markdown]
# <a href="https://colab.research.google.com/github/DarkL19ht/Image-Inversion----COMPUTER-VISION-/blob/main/tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2;

# %%
import numpy as np;

# %%
from google.colab.patches import cv2_imshow;

# %%
# Task - MODIFYING THE PIXELS IN THE 3RD QUADRANT

# %%
img = cv2.imread('waves.jpeg');

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
print(img.shape);
# Out:
# (1024, 1024, 3)

# %%
height, width, channel = img.shape;

# %%
img_new = img.copy()

# %%
alpha = 127
for i in range (height // 2):
  for j in range (width // 2):
    img_new[i,j] = alpha
cv2_imshow(img_new)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
# Task - CREATING A BLANK IMAGE
